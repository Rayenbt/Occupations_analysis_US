# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("all_data_M_2023.xlsx",sheet_name="All May 2023 data")

# %%
data.head(20)
# Out:
#     AREA AREA_TITLE  AREA_TYPE PRIM_STATE   NAICS     NAICS_TITLE  \
# 0     99       U.S.          1         US  000000  Cross-industry
# 1     99       U.S.          1         US  000000  Cross-industry
# 2     99       U.S.          1         US  000000  Cross-industry
# 3     99       U.S.          1         US  000000  Cross-industry
# 4     99       U.S.          1         US  000000  Cross-industry
# 5     99       U.S.          1         US  000000  Cross-industry
# 6     99       U.S.          1         US  000000  Cross-industry
# 7     99       U.S.          1         US  000000  Cross-industry
# 8     99       U.S.          1         US  000000  Cross-industry
# 9     99       U.S.          1         US  000000  Cross-industry
# 10    99       U.S.          1         US  000000  Cross-industry
# 11    99       U.S.          1         US  000000  Cross-industry
# 12    99       U.S.          1         US  000000  Cross-industry
# 13    99       U.S.          1         US  000000  Cross-industry
# 14    99       U.S.          1         US  000000  Cross-industry
# 15    99       U.S.          1         US  000000  Cross-industry
# 16    99       U.S.          1         US  000000  Cross-industry
# 17    99       U.S.          1         US  000000  Cross-industry
# 18    99       U.S.          1         US  000000  Cross-industry
# 19    99       U.S.          1         US  000000  Cross-industry
#
#            I_GROUP  OWN_CODE OCC_CODE  \
# 0   cross-industry      1235  00-0000
# 1   cross-industry      1235  11-0000
# 2   cross-industry      1235  11-1000
# 3   cross-industry      1235  11-1010
# 4   cross-industry      1235  11-1011
# 5   cross-industry      1235  11-1020
# 6   cross-industry      1235  11-1021
# 7   cross-industry      1235  11-1030
# 8   cross-industry      1235  11-1031
# 9   cross-industry      1235  11-2000
# 10  cross-industry      1235  11-2010
# 11  cross-industry      1235  11-2011
# 12  cross-industry      1235  11-2020
# 13  cross-industry      1235  11-2021
# 14  cross-industry      1235  11-2022
# 15  cross-industry      1235  11-2030
# 16  cross-industry      1235  11-2032
# 17  cross-industry      1235  11-2033
# 18  cross-industry      1235  11-3000
# 19  cross-industry      1235  11-3010
#
#                                             OCC_TITLE  ... H_MEDIAN H_PCT75  \
# 0                                     All Occupations  ...    23.11   37.01
# 1                              Management Occupations  ...    56.19   81.29
# 2                                      Top Executives  ...    49.74   79.57
# 3                                    Chief Executives  ...    99.37       #
# 4                                    Chief Executives  ...    99.37       #
# 5                     General and Operations Managers  ...    48.69   77.06
# 6                     General and Operations Managers  ...    48.69   77.06
# 7                                         Legislators  ...        *       *
# 8                                         Legislators  ...        *       *
# 9   Advertising, Marketing, Promotions, Public Rel...  ...    67.23   96.15
# 10                Advertising and Promotions Managers  ...     63.4   90.64
# 11                Advertising and Promotions Managers  ...     63.4   90.64
# 12                       Marketing and Sales Managers  ...    68.17   97.11
# 13                                 Marketing Managers  ...    75.78     100
# 14                                     Sales Managers  ...    64.98   94.57
# 15          Public Relations and Fundraising Managers  ...    62.73   85.66
# 16                          Public Relations Managers  ...    64.79   92.23
# 17                               Fundraising Managers  ...    57.31    78.2
# 18                    Operations Specialties Managers  ...    65.47   88.22
# 19    Administrative Services and Facilities Managers  ...    50.44   66.45
#
#    H_PCT90 A_PCT10 A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0     58.4   29050   35660    48060   76980  121470    NaN    NaN
# 1   111.36   54550   78330   116880  169090  231620    NaN    NaN
# 2        #   46400   66170   103460  165500       #    NaN    NaN
# 3        #   80000  130840   206680       #       #    NaN    NaN
# 4        #   80000  130840   206680       #       #    NaN    NaN
# 5   111.59   46340   65180   101280  160290  232110    NaN    NaN
# 6   111.59   46340   65180   101280  160290  232110    NaN    NaN
# 7        *   21010   28810    47290   82200  129510   True    NaN
# 8        *   21010   28810    47290   82200  129510   True    NaN
# 9        #   69170   99180   139850  199990       #    NaN    NaN
# 10       #   63580   88810   131870  188530       #    NaN    NaN
# 11       #   63580   88810   131870  188530       #    NaN    NaN
# 12       #   68660   99780   141780  201990       #    NaN    NaN
# 13       #   79600  108000   157620  208000       #    NaN    NaN
# 14       #   63700   93540   135160  196700       #    NaN    NaN
# 15       #   74030   96180   130480  178180       #    NaN    NaN
# 16       #   76160   99180   134760  191840       #    NaN    NaN
# 17  102.27   68800   86880   119200  162660  212730    NaN    NaN
# 18       #   76320  100690   136170  183500       #    NaN    NaN
# 19   86.41   61860   80170   104900  138220  179730    NaN    NaN
#
# [20 rows x 32 columns]

# %%
# As mentioned in the assignment 'You have been tasked with creating visualisations to gain insights into employment in 
# fields involving AI, Data Science and Software Development. '
# So I will filter jobs that I personally consider relevant to the task needed 
relevant_jobs = ['15-1220', ## Computer and Information research scientist highly linked to AI Jobs
                '15-1250', ## combines software and web developers, programmers and testers
                '15-2050' ## data scientist
                ]

## This new dataframe will group the jobs we are interested in all the U.S
filtered_data = data[data['OCC_CODE'].isin(relevant_jobs)]
filtered_data.head(15)
# Out:
#       AREA AREA_TITLE  AREA_TYPE PRIM_STATE   NAICS  \
# 137     99       U.S.          1         US  000000
# 147     99       U.S.          1         US  000000
# 164     99       U.S.          1         US  000000
# 1535    99       U.S.          1         US  000001
# 1545    99       U.S.          1         US  000001
# 1562    99       U.S.          1         US  000001
# 2855    99       U.S.          1         US      11
# 3213    99       U.S.          1         US      21
# 3222    99       U.S.          1         US      21
# 3729    99       U.S.          1         US      22
# 3739    99       U.S.          1         US      22
# 3750    99       U.S.          1         US      22
# 4267    99       U.S.          1         US      23
# 4278    99       U.S.          1         US      23
# 5007    99       U.S.          1         US      42
#
#                                         NAICS_TITLE  \
# 137                                  Cross-industry
# 147                                  Cross-industry
# 164                                  Cross-industry
# 1535         Cross-industry, Private Ownership only
# 1545         Cross-industry, Private Ownership only
# 1562         Cross-industry, Private Ownership only
# 2855     Agriculture, Forestry, Fishing and Hunting
# 3213  Mining, Quarrying, and Oil and Gas Extraction
# 3222  Mining, Quarrying, and Oil and Gas Extraction
# 3729                                      Utilities
# 3739                                      Utilities
# 3750                                      Utilities
# 4267                                   Construction
# 4278                                   Construction
# 5007                                Wholesale Trade
#
#                         I_GROUP  OWN_CODE OCC_CODE  \
# 137              cross-industry      1235  15-1220
# 147              cross-industry      1235  15-1250
# 164              cross-industry      1235  15-2050
# 1535  cross-industry, ownership         5  15-1220
# 1545  cross-industry, ownership         5  15-1250
# 1562  cross-industry, ownership         5  15-2050
# 2855                     sector         5  15-1250
# 3213                     sector         5  15-1250
# 3222                     sector         5  15-2050
# 3729                     sector         5  15-1220
# 3739                     sector         5  15-1250
# 3750                     sector         5  15-2050
# 4267                     sector         5  15-1250
# 4278                     sector         5  15-2050
# 5007                     sector         5  15-1220
#
#                                               OCC_TITLE  ... H_MEDIAN H_PCT75  \
# 137        Computer and Information Research Scientists  ...    69.75   89.02
# 147   Software and Web Developers, Programmers, and ...  ...    61.11   78.66
# 164                                     Data Scientists  ...    51.93   70.99
# 1535       Computer and Information Research Scientists  ...    82.78  100.89
# 1545  Software and Web Developers, Programmers, and ...  ...    61.52   78.92
# 1562                                    Data Scientists  ...     52.8   72.23
# 2855  Software and Web Developers, Programmers, and ...  ...    38.69   62.78
# 3213  Software and Web Developers, Programmers, and ...  ...    61.61    69.1
# 3222                                    Data Scientists  ...    50.52   71.03
# 3729       Computer and Information Research Scientists  ...    63.67   64.04
# 3739  Software and Web Developers, Programmers, and ...  ...    59.79   70.23
# 3750                                    Data Scientists  ...    48.53      64
# 4267  Software and Web Developers, Programmers, and ...  ...     41.9   55.96
# 4278                                    Data Scientists  ...    34.42   49.23
# 5007       Computer and Information Research Scientists  ...    81.82   98.87
#
#      H_PCT90 A_PCT10 A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 137   112.07   81450  109990   145080  185160  233110    NaN    NaN
# 147    97.47   66930   92650   127120  163610  202730    NaN    NaN
# 164    88.51   61070   79810   108020  147670  184090    NaN    NaN
# 1535       #   99620  135940   172190  209850       #    NaN    NaN
# 1545   97.98   67330   94120   127970  164160  203790    NaN    NaN
# 1562   89.42   61470   80510   109820  150230  186000    NaN    NaN
# 2855   70.22   42310   48420    80480  130590  146070    NaN    NaN
# 3213   77.49   79120  103480   128160  143730  161170    NaN    NaN
# 3222   78.73   49940   67320   105090  147740  163760    NaN    NaN
# 3729   79.37  103250  107350   132430  133200  165100    NaN    NaN
# 3739   81.82   77690   99980   124360  146080  170180    NaN    NaN
# 3750   77.51   64900   80000   100940  133110  161210    NaN    NaN
# 4267   69.26   50620   68020    87150  116400  144060    NaN    NaN
# 4278   66.22   46800   56800    71600  102390  137740    NaN    NaN
# 5007  105.32  117880  143440   170180  205640  219070    NaN    NaN
#
# [15 rows x 32 columns]

# %%
filtered_data.columns
# Out:
# Index(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'PRIM_STATE', 'NAICS', 'NAICS_TITLE',
#        'I_GROUP', 'OWN_CODE', 'OCC_CODE', 'OCC_TITLE', 'O_GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'PCT_RPT',
#        'H_MEAN', 'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN',
#        'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75',
#        'A_PCT90', 'ANNUAL', 'HOURLY'],
#       dtype='object')

# %%
##Changed the dataset column tot_emp from a string to numeric, errors will become Nan through 'coerce'
filtered_data.loc[:,'TOT_EMP'] = pd.to_numeric(filtered_data['TOT_EMP'], errors='coerce')
#group filtered data based on the job titles and we do the sum
total_employees = filtered_data.groupby(['OCC_TITLE'])['TOT_EMP'].sum()
total_employees
# Out:
# OCC_TITLE
# Computer and Information Research Scientists               197950.0
# Data Scientists                                           1028170.0
# Software and Web Developers, Programmers, and Testers    11274000.0
# Name: TOT_EMP, dtype: object

# %%
plt.figure(figsize=(12,8))
plt.pie(total_employees,labels=total_employees.index,autopct='%1.1f%%')
plt.title('Total Employees distribution by Occupation')
plt.show()

# %% [markdown]
# The previous plot is a pie plot that I've used to see the overall distribution of the jobs in the dataset in percentages as part of investigating the dataset, pie plot works best in this case to have an idea about the weight of each job we have.
# I noticed that a huge amount of people are into software and web development with 90.2%  while only 8.2% are into data science however I found only 1.2% are into computer and information reasearch science.

# %%
filtered_data.loc[:,'A_MEAN'] = pd.to_numeric(filtered_data['A_MEAN'], errors='coerce')
job_wage = filtered_data.groupby('OCC_TITLE')['A_MEAN'].mean()
job_wage.head()
# Out:
# OCC_TITLE
# Computer and Information Research Scientists             147434.578313
# Data Scientists                                          105780.982456
# Software and Web Developers, Programmers, and Testers    108349.546599
# Name: A_MEAN, dtype: object

# %%
plt.figure(figsize=(14,6))
jobs= job_wage.index
salaries = job_wage.values
barplot = plt.bar(jobs,salaries,color=['indianred','steelblue','mediumseagreen'])
plt.title("Average Salary by Job title")
plt.xlabel('Job title')
plt.ylabel('Average Salary')
plt.grid()
plt.legend(barplot,jobs,title="job title")
plt.show()

# %% [markdown]
# The second plot is a bar plot of the average salary for the 3 broad jobs we have in our data, I did this plot to have an idea if the proportion of jobs would affect the salaries which apparently it doesn't as Computer and Information research scientists make the most, around 147k a year despite being the lowest job category in terms of total employment, Data scientists and software and web devlopers, programmers and testers come next with close salaries, with roughly 105k/year and 108k respectively.
